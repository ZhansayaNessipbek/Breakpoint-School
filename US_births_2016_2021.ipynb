# %% [markdown]
# <a href="https://colab.research.google.com/github/ZhansayaNessipbek/Breakpoint-School/blob/main/US_births_2016_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #US Births by Year, State, and Education Level
#
# This dataset provides birth rates and related data across the 50 states and DC from 2016 to 2021.   The data  includes detailed information such as number of births, gender, birth weight, state, and year of the delivery. A particular emphasis is given to detailed information on the mother's educational level. With this dataset, one can, for example, examine trends and patterns in birth rates across different academic groups and geographic locations.
#
# link to source: https://www.kaggle.com/datasets/danbraswell/temporary-us-births

# %% [markdown]
# ##Description:
# - State – Full name of the U.S. state where the birth was recorded
# - State Abbreviation – Two-letter postal abbreviation for the state
# - Year – The year when the births were recorded
# - Gender – The sex of the newborn
# - Education Level of Mother – The descriptive education level of the mother at the time of birth
# - Education Level Code – Numeric code representing the mother’s education level, usually mapped to categories
# - Number of Births – Total count of births recorded for the specified grouping
# - Average Age of Mother (years) – Average age in years of mothers for the births in that group
# - Average Birth Weight (g) – Average weight of the newborns in grams for the given group

# %% [markdown]
# #Tools Used:
# Python — for data processing and analysis
#
# Pandas — for data manipulation and aggregation
#
# NumPy — for numerical operations and array handling
#
# Matplotlib — for creating static, animated, and interactive visualizations
#
# Seaborn — for statistical data visualization built on top of Matplotlib

# %% [markdown]
# # Completed Analyses:
# - Number of Births by Gender
#
# - Average Newborn Weight by Sex
#
# - Relationship Between Mother’s Age and Birth Weight
#
# - Analysis of Number of Births by Mother's Age Group
#
# - Education Level Distribution Across Age Groups
#
# - Average Age of Mother by Education Level
#
# - Total Number of Births by Education Level
#
# - Total Percentage of Births by Education Level
#
# - Number of Births by Education Level
#
# - Yearly Birth Counts and Their Percentage Distribution
#
# - Yearly Birth Distribution by Gender with Percentages
#
# - Pivot Table of Births by Age Group and Education Level
#
# - Births by Education Level Code per State (Pivot Table)
#
# - Births by Education Level in Top 10 States (with Totals, Sorted)
#
# - Percentage Breakdown of Births by Education Level in Top 10 States
#
# - Education Level Distribution in the 10 States with the Fewest Births
#
# - Comparison of Births by Education Level Code: Pre vs. During/After COVID
#
# - Percentage of Births by State: Pre vs. During/After COVID (Top 10 States)
#
# - Impact of COVID-19 on U.S. Births (2016–2021)

# %% [markdown]
# #Visualizations:
# - Distribution of Births by Gender with Percent Labels
#
# - Relation Between Mother’s Age and Birth Weight
#
# - Number of Births by Mother's Age Group
#
# - Education Level Distribution Across Age Groups
#
# - Yearly Birth Distribution by Gender with Percentages
#
# - Percentage of Birth by Education Level Code
#
# - Heatmap of Percentage of Births by Age Group and Education Level Code
#
# - Percentage of Births by Education Level Code Over Time
#
# - Percentage of Births by Education Level in Top 10 States
#
# - Education Level Birth Percentages for Bottom 10 States
#
# - Percentage of Births by Education Level Code: Pre vs. During/After COVID
#
# - Percentage of Births by State: Pre vs. During/After COVID (Top 10 States)
#
# - Impact of COVID-19 on U.S. Births (2016–2021)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv('us_births_2016_2021.csv')
# Out:
#         State State Abbreviation  Year Gender  \
# 0     Alabama                 AL  2016      F
# 1     Alabama                 AL  2016      F
# 2     Alabama                 AL  2016      F
# 3     Alabama                 AL  2016      F
# 4     Alabama                 AL  2016      F
# ...       ...                ...   ...    ...
# 5491  Wyoming                 WY  2021      M
# 5492  Wyoming                 WY  2021      M
# 5493  Wyoming                 WY  2021      M
# 5494  Wyoming                 WY  2021      M
# 5495  Wyoming                 WY  2021      M
#
#                               Education Level of Mother  Education Level Code  \
# 0                                     8th grade or less                     1
# 1                9th through 12th grade with no diploma                     2
# 2                 High school graduate or GED completed                     3
# 3                 Some college credit, but not a degree                     4
# ...

# %%
df=pd.read_csv('us_births_2016_2021.csv')

# %%
df.head()
# Out:
#      State State Abbreviation  Year Gender  \
# 0  Alabama                 AL  2016      F
# 1  Alabama                 AL  2016      F
# 2  Alabama                 AL  2016      F
# 3  Alabama                 AL  2016      F
# 4  Alabama                 AL  2016      F
#
#                 Education Level of Mother  Education Level Code  \
# 0                       8th grade or less                     1
# 1  9th through 12th grade with no diploma                     2
# 2   High school graduate or GED completed                     3
# 3   Some college credit, but not a degree                     4
# 4               Associate degree (AA, AS)                     5
#
#    Number of Births  Average Age of Mother (years)  Average Birth Weight (g)
# 0              1052                           27.8                    3116.9
# 1              3436                           24.1                    3040.0
# 2              8777                           25.4                    3080.0
# ...

# %%
df.tail()
# Out:
#         State State Abbreviation  Year Gender  \
# 5491  Wyoming                 WY  2021      M
# 5492  Wyoming                 WY  2021      M
# 5493  Wyoming                 WY  2021      M
# 5494  Wyoming                 WY  2021      M
# 5495  Wyoming                 WY  2021      M
#
#                               Education Level of Mother  Education Level Code  \
# 5491                          Associate degree (AA, AS)                     5
# 5492                     Bachelor's degree (BA, AB, BS)                     6
# 5493      Master's degree (MA, MS, MEng, MEd, MSW, MBA)                     7
# 5494  Doctorate (PhD, EdD) or Professional Degree (M...                     8
# 5495                              Unknown or Not Stated                    -9
#
#       Number of Births  Average Age of Mother (years)  \
# 5491               401                           29.2
# 5492               657                           30.7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5496 entries, 0 to 5495
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   State                          5496 non-null   object
#  1   State Abbreviation             5496 non-null   object
#  2   Year                           5496 non-null   int64
#  3   Gender                         5496 non-null   object
#  4   Education Level of Mother      5496 non-null   object
#  5   Education Level Code           5496 non-null   int64
#  6   Number of Births               5496 non-null   int64
#  7   Average Age of Mother (years)  5496 non-null   float64
#  8   Average Birth Weight (g)       5496 non-null   float64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 386.6+ KB

# %%
df.isna().sum()
# Out:
# State                            0
# State Abbreviation               0
# Year                             0
# Gender                           0
# Education Level of Mother        0
# Education Level Code             0
# Number of Births                 0
# Average Age of Mother (years)    0
# Average Birth Weight (g)         0
# dtype: int64

# %%
df.shape
# Out:
# (5496, 9)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#               Year  Education Level Code  Number of Births  \
# count  5496.000000           5496.000000       5496.000000
# mean   2018.500728              3.026201       4115.443959
# std       1.707554              4.733406       6687.036797
# min    2016.000000             -9.000000         10.000000
# 25%    2017.000000              2.000000        559.000000
# 50%    2019.000000              4.000000       1692.000000
# 75%    2020.000000              6.000000       5140.000000
# max    2021.000000              8.000000      59967.000000
#
#        Average Age of Mother (years)  Average Birth Weight (g)
# count                    5496.000000               5496.000000
# mean                       29.552274               3250.887627
# std                         2.779735                114.456090
# min                        23.100000               2451.900000
# 25%                        27.500000               3182.200000
# ...

# %%
#Number of Births by Gender
grouped_gender=df.groupby('Gender')['Number of Births'].sum()
grouped_gender_percent=((grouped_gender/grouped_gender.sum()*100)).round(1).astype(str)+'%'
result=pd.concat([grouped_gender,grouped_gender_percent],axis=1)
result.columns=['Number of Births', 'Percentage']
result
# Out:
#         Number of Births Percentage
# Gender
# F               11050314      48.9%
# M               11568166      51.1%

# %%
#Distribution of Births by Gender with Percent Labels
grouped_gender_percent=((grouped_gender/grouped_gender.sum()*100)).round(1)
plt.figure(figsize=(6,4))
plt.pie(
    grouped_gender,
    labels=[f'{gender}' for gender, percent in zip(grouped_gender.index, grouped_gender_percent)],
    autopct='%1.1f%%',
    colors=['lightpink', 'lightblue'],
    startangle=90
)
plt.title('Number of Births by Gender')
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
#Average Newborn Weight by Sex
df.groupby('Gender')['Average Birth Weight (g)'].mean().round()
# Out:
# Gender
# F    3195.0
# M    3307.0
# Name: Average Birth Weight (g), dtype: float64

# %%
#Relation Between Mother’s Age and Birth Weight
plt.figure(figsize=(8, 6))
sns.regplot(x='Average Age of Mother (years)', y='Average Birth Weight (g)', data=df)
plt.title('Relation Between Mother’s Age and Birth Weight')
plt.xlabel('Average Age of Mother (years)')
plt.ylabel('Average Birth Weight (g)')
plt.tight_layout()
plt.show()

# %%
#Analysis of Number of Births by Mother's Age Group
bins = [23, 25, 27, 29, 31, 33, 35, 37]
labels = [f'{i}-{i+1}' for i in range(23, 37, 2)]

df['Age Group'] = pd.cut(
    df['Average Age of Mother (years)'],
    bins=bins,
    labels=labels,
    right=False
)


grouped_births = df.groupby('Age Group')['Number of Births'].sum()


grouped_births_percent = round(grouped_births / grouped_births.sum() * 100, 2).astype(str) + '%'


result = pd.concat([grouped_births, grouped_births_percent], axis=1)
result.columns = ['Number of Births', 'Percentage']

result
# Out:
# /tmp/ipython-input-53-3396682932.py:13: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_births = df.groupby('Age Group')['Number of Births'].sum()
#            Number of Births Percentage
# Age Group
# 23-24                789801      3.49%
# 25-26               5016351     22.18%
# 27-28               6101943     26.98%
# 29-30               3916061     17.31%
# 31-32               4962781     21.94%
# 33-34               1807415      7.99%
# 35-36                 24128      0.11%

# %%
#Number of Births by Mother's Age Group
grouped_births_percent=round(grouped_births/grouped_births.sum()*100,2)
plt.figure(figsize=(6,5))
bars = plt.bar(grouped_births_percent.index, grouped_births_percent.values)
plt.title('Number of Births by Mother\'s Age Group')
plt.xlabel('Age Group')
plt.ylabel('Percentage')
plt.tight_layout()

for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, height + 0.1, f'{height}%',
             ha='center', va='bottom')

plt.show()

# %%
#Births by Age Group and Education Level Barplot
grouped = df.groupby(['Age Group', 'Education Level Code'])['Number of Births'].sum().reset_index()

plt.figure(figsize=(16,8))

palette = sns.color_palette("tab10", n_colors=grouped['Education Level Code'].nunique())

sns.barplot(
    data=grouped,
    x='Age Group',
    y='Number of Births',
    hue='Education Level Code',
    palette=palette,
    ci=None
)

plt.title('Number of Births by Age Group and Education Level', fontsize=18, weight='bold')
plt.ylabel('Number of Births', fontsize=14)
plt.xlabel('Age Group', fontsize=14)

plt.xticks(rotation=0, fontsize=12)
plt.yticks(fontsize=12)

plt.legend(title='Education Level Code', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=12, title_fontsize=13)

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-84-3509357737.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped = df.groupby(['Age Group', 'Education Level Code'])['Number of Births'].sum().reset_index()
# /tmp/ipython-input-84-3509357737.py:8: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(

# %%
#Average Age of Mother by Education Level
df.groupby('Education Level of Mother')['Average Age of Mother (years)'].mean().round()
# Out:
# Education Level of Mother
# 8th grade or less                                                      29.0
# 9th through 12th grade with no diploma                                 25.0
# Associate degree (AA, AS)                                              30.0
# Bachelor's degree (BA, AB, BS)                                         31.0
# Doctorate (PhD, EdD) or Professional Degree (MD, DDS, DVM, LLB, JD)    34.0
# High school graduate or GED completed                                  26.0
# Master's degree (MA, MS, MEng, MEd, MSW, MBA)                          33.0
# Some college credit, but not a degree                                  28.0
# Unknown or Not Stated                                                  29.0
# Name: Average Age of Mother (years), dtype: float64

# %%
#Births summed by education level
edu_map = {
    1: '8th grade or less',
    2: '9th through 12th grade with no diploma',
    3: 'High school graduate or GED completed',
    4: 'Some college credit, but not a degree',
    5: 'Associate degree (AA, AS)',
    6: "Bachelor's degree (BA, AB, BS)",
    7: "Master's degree (MA, MS, MEng, MEd, MSW, MBA)",
    8: 'Doctorate (PhD, EdD) or Professional Degree (MD, DDS, DVM, LLB, JD)',
    -9: 'Unknown or Not Stated'
}
df['Education Level'] = df['Education Level Code'].map(edu_map)
births_by_education = df.groupby(['Education Level','Education Level Code'])['Number of Births'].sum()
births_by_education_percent = (births_by_education / births_by_education.sum() * 100).round(1).astype(str) + '%'
result=pd.concat([births_by_education,births_by_education_percent],axis=1)
result.columns=['Number of Births','Percentage']
result = result.reset_index().sort_values('Education Level Code')
result
# Out:
#                                      Education Level  Education Level Code  \
# 8                              Unknown or Not Stated                    -9
# 0                                  8th grade or less                     1
# 1             9th through 12th grade with no diploma                     2
# 5              High school graduate or GED completed                     3
# 7              Some college credit, but not a degree                     4
# 2                          Associate degree (AA, AS)                     5
# 3                     Bachelor's degree (BA, AB, BS)                     6
# 6      Master's degree (MA, MS, MEng, MEd, MSW, MBA)                     7
# 4  Doctorate (PhD, EdD) or Professional Degree (M...                     8
#
#    Number of Births Percentage
# 8            312426       1.4%
# 0            708850       3.1%
# 1           2086382       9.2%
# 5           5775918      25.5%
# 7           4425269      19.6%
# ...

# %%
#Percentage of Births by Education Level Code
import matplotlib.patches as mpatches
def get_color(code):
    if code in [1, 2, 3]:
        return 'red'
    elif code in [4, 5]:
        return 'orange'
    elif code in [6, 7, 8]:
        return 'green'
    else:
        return 'gray'

result['Percentage_num'] = result['Percentage'].str.rstrip('%').astype(float)
colors = [get_color(code) for code in result['Education Level Code']]

plt.figure(figsize=(10, 6))

x_labels = result['Education Level Code'].astype(str)
bars = plt.bar(x_labels, result['Percentage_num'], color=colors)

plt.xlabel('Education Level Code')
plt.ylabel('Percentage of Births (%)')
plt.title('Percentage of Births by Education Level Code')

for bar, pct in zip(bars, result['Percentage']):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height + 0.1, pct,
             ha='center', va='bottom', fontsize=10)


legend_handles = [
    mpatches.Patch(color='red', label='Low Education (1, 2, 3)'),
    mpatches.Patch(color='orange', label='Medium Education (4, 5)'),
    mpatches.Patch(color='green', label='High Education (6, 7, 8)'),
    mpatches.Patch(color='gray', label='Unknown/Other(-9)')
]
plt.legend(handles=legend_handles, title='Education Level Categories', loc='upper right')

plt.tight_layout()
plt.show()

# %%
#Sum percentage of births by education group
def assign_group(code):
    if code in [1, 2, 3]:
        return 'Low Education'
    elif code in [4, 5]:
        return 'Medium Education'
    elif code in [6, 7, 8]:
        return 'High Education'
    else:
        return 'Other'


result['Education Group'] = result['Education Level Code'].apply(assign_group)

result['Percentage_num'] = result['Percentage'].str.rstrip('%').astype(float)

percentage_sum_by_group = result.groupby('Education Group')['Percentage_num'].sum().round(1)

percentage_sum_by_group
# Out:
# Education Group
# High Education      33.0
# Low Education       37.8
# Medium Education    27.9
# Other                1.4
# Name: Percentage_num, dtype: float64

# %%
#Number of Births by Education Level
#Students classified as ‘with education group’ are those holding Bachelor’s, Master’s, or Doctorate degrees.
education_births=df[df['Education Level Code']>5]['Number of Births'].sum()
non_education_births=df[df['Education Level Code']<=5]['Number of Births'].sum()
result = pd.DataFrame({
    'Education Group': ['With Education', 'Without Education'],
    'Number of Births': [education_births, non_education_births]})
result
# Out:
#      Education Group  Number of Births
# 0     With Education           7441935
# 1  Without Education          15176545

# %%
#Yearly Birth Counts and Their Percentage Distribution
birth_per_year=df.groupby('Year')['Number of Births'].sum()
birth_per_year_percent=(birth_per_year/birth_per_year.sum()*100).round(1).astype(str)+'%'
result=pd.concat([birth_per_year,birth_per_year_percent],axis=1)
result.columns=['Number of Births','Percentage']
result
# Out:
#       Number of Births Percentage
# Year
# 2016           3945853      17.4%
# 2017           3855479      17.0%
# 2018           3791707      16.8%
# 2019           3747531      16.6%
# 2020           3613633      16.0%
# 2021           3664277      16.2%

# %%
# Yearly Birth Distribution by Gender with Percentages
births_by_year_gender = df.groupby(['Year', 'Gender'])['Number of Births'].sum().unstack()
births_by_year_gender = births_by_year_gender.sort_index()
total_births_per_year = births_by_year_gender.sum(axis=1)
births_by_year_gender_percent = (births_by_year_gender.div(total_births_per_year, axis=0) * 100).round(1).astype(str) + '%'
result = pd.concat([births_by_year_gender, births_by_year_gender_percent], axis=1)
result.columns = ['Female', 'Male', 'Female %', 'Male %']
result = result[['Female', 'Female %', 'Male', 'Male %']]

result
# Out:
#        Female Female %     Male Male %
# Year
# 2016  1927676    48.9%  2018177  51.1%
# 2017  1882608    48.8%  1972871  51.2%
# 2018  1853528    48.9%  1938179  51.1%
# 2019  1830085    48.8%  1917446  51.2%
# 2020  1765547    48.9%  1848086  51.1%
# 2021  1790870    48.9%  1873407  51.1%

# %%
#Percentage of Births by Gender per Year
import matplotlib.pyplot as plt

result['Female %'] = result['Female %'].str.rstrip('%').astype(float)
result['Male %'] = result['Male %'].str.rstrip('%').astype(float)

plt.figure(figsize=(8,4))
plt.plot(result.index, result['Female %'], marker='o', label='Female %')
plt.plot(result.index, result['Male %'], marker='o', label='Male %')

plt.title('Percentage of Births by Gender per Year')
plt.xlabel('Year')
plt.ylabel('Percentage (%)')
plt.ylim(45, 55)
plt.grid(True)
plt.legend()
plt.show()

# %%
#Pivot Table of Births by Age Group and Education Level
edu_order = [
    'Unknown or Not Stated',
    '8th grade or less',
    '9th through 12th grade with no diploma',
    'High school graduate or GED completed',
    'Some college credit, but not a degree',
    'Associate degree (AA, AS)',
    "Bachelor's degree (BA, AB, BS)",
    "Master's degree (MA, MS, MEng, MEd, MSW, MBA)",
    'Doctorate (PhD, EdD) or Professional Degree (MD, DDS, DVM, LLB, JD)'
]

df['Education Level'] = df['Education Level Code'].map(edu_map)

pivot_table = df.pivot_table(
    index='Age Group',
    columns='Education Level',
    values='Number of Births',
    aggfunc='sum',
    fill_value=0
)

pivot_table.columns = pd.CategoricalIndex(pivot_table.columns, categories=edu_order, ordered=True)
pivot_table = pivot_table.sort_index(axis=1)

pivot_table
# Out:
# /tmp/ipython-input-61-1429684143.py:16: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   pivot_table = df.pivot_table(
# Education Level  Unknown or Not Stated  8th grade or less  \
# Age Group
# 23-24                                0                  0
# 25-26                             1087               6309
# 27-28                            32655             184626
# 29-30                           137260             394461
# 31-32                           141258             123432
# 33-34                              166                 22
# 35-36                                0                  0
#
# Education Level  9th through 12th grade with no diploma  \
# Age Group
# 23-24                                            774377
# 25-26                                           1090306
# ...

# %%
#Heatmap of Percentage of Births by Age Group and Education Level Code
births = df.groupby(['Age Group', 'Education Level Code'])['Number of Births'].sum().reset_index()
births_pivot = births.pivot(index='Age Group', columns='Education Level Code', values='Number of Births').fillna(0)
births_pct = births_pivot.div(births_pivot.sum(axis=1), axis=0) * 100
plt.figure(figsize=(12, 7))
sns.heatmap(births_pct, annot=True, fmt=".1f", cmap='coolwarm', cbar_kws={'label': 'Percentage of Births (%)'})
plt.title('Percentage of Births by Age Group and Education Level Code')
plt.ylabel('Age Group')
plt.xlabel('Education Level Code')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-62-4057149659.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   births = df.groupby(['Age Group', 'Education Level Code'])['Number of Births'].sum().reset_index()

# %%
#Percentage of Births by Education Level Code Over Time
births_by_edu_year = df.groupby(['Year', 'Education Level Code'])['Number of Births'].sum().reset_index()
total_births_per_year = births_by_edu_year.groupby('Year')['Number of Births'].transform('sum')
births_by_edu_year['Percentage'] = (births_by_edu_year['Number of Births'] / total_births_per_year) * 100

pivot = births_by_edu_year.pivot(index='Year', columns='Education Level Code', values='Percentage')
pivot.plot(marker='o', figsize=(12, 6))
plt.title('Percentage of Births by Education Level Code Over Time')
plt.ylabel('Percentage of Births (%)')
plt.xlabel('Year')
plt.legend(title='Education Level Code', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
#Percentage Breakdown of Births by Education Level in Top 10 States

top_states = df.groupby('State')['Number of Births'].sum().sort_values(ascending=False).head(10).index

top_states_df = df[df['State'].isin(top_states)]

education_by_top_states = top_states_df.groupby(['State', 'Education Level Code'])['Number of Births'].sum().unstack().fillna(0)

education_by_top_states['Total Births'] = education_by_top_states.sum(axis=1)

education_percent_top_states = education_by_top_states.div(education_by_top_states['Total Births'], axis=0) * 100

education_percent_top_states = education_percent_top_states.round(1).astype(str) + '%'

education_percent_top_states = education_percent_top_states.drop(columns='Total Births')

education_percent_top_states
# Out:
# Education Level Code    -9     1      2      3      4      5      6      7  \
# State
# California            6.0%  3.6%   8.3%  23.8%  19.2%   6.6%  20.2%   9.2%
# Florida               1.0%  2.9%   8.3%  30.9%  18.0%  10.3%  18.9%   7.5%
# Georgia               0.5%  3.3%   9.4%  31.2%  17.9%   7.4%  21.4%   7.1%
# Illinois              1.6%  2.2%   7.9%  22.5%  19.1%   8.0%  23.1%  12.5%
# Michigan              0.9%  2.0%   8.6%  25.7%  22.6%   8.6%  20.3%   8.7%
# New York              0.6%  4.2%   9.8%  22.8%  15.4%   8.0%  20.6%  14.9%
# North Carolina        0.3%  3.4%   9.6%  24.2%  21.1%   9.5%  20.4%   8.9%
# Ohio                  0.3%  3.6%   9.1%  27.9%  18.7%   9.0%  19.5%   9.2%
# Pennsylvania          0.8%  3.4%   8.2%  25.1%  16.7%   8.6%  21.7%  12.0%
# Texas                 0.2%  3.3%  12.7%  28.1%  21.1%   6.6%  18.8%   7.1%
#
# Education Level Code     8
# State
# California            3.1%
# Florida               2.3%
# Georgia               1.7%
# ...

# %%
#Percentage of Births by Education Level in Top 10 States
education_percent_plot = education_percent_top_states.astype(str).applymap(lambda x: float(x.strip('%')))
education_percent_plot.plot(
    kind='bar',
    stacked=True,
    figsize=(12, 6),
    colormap='tab20'
)

plt.title('Percentage of Births by Education Level in Top 10 States')
plt.ylabel('Percentage (%)')
plt.xlabel('State')
plt.legend(title='Education Level Code', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-76-2868482322.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   education_percent_plot = education_percent_top_states.astype(str).applymap(lambda x: float(x.strip('%')))

# %%
#Percentage Distribution of Births by Education Level in the 10 States with the Fewest Births"
bottom_states = df.groupby('State')['Number of Births'].sum().sort_values(ascending=True).head(10).index
bottom_states_df = df[df['State'].isin(bottom_states)]
education_by_bottom_states = bottom_states_df.groupby(['State', 'Education Level Code'])['Number of Births'].sum().unstack().fillna(0)
education_by_bottom_states = education_by_bottom_states[sorted(education_by_bottom_states.columns)]
education_by_bottom_states['Total Births'] = education_by_bottom_states.sum(axis=1)
education_by_bottom_states = education_by_bottom_states.sort_values('Total Births', ascending=True)
education_percent_bottom_states = education_by_bottom_states.div(education_by_bottom_states['Total Births'], axis=0) * 100
education_percent_bottom_states = education_percent_bottom_states.round(1).astype(str) + '%'
education_percent_bottom_states = education_percent_bottom_states.drop(columns='Total Births')
education_percent_bottom_states
# Out:
# Education Level Code    -9     1      2      3      4      5      6      7  \
# State
# Vermont               0.6%  0.8%   6.3%  23.6%  17.9%   7.4%  25.4%  14.0%
# Wyoming               1.0%  1.1%   8.5%  24.4%  25.0%  11.9%  18.9%   7.2%
# District of Columbia  1.1%  3.1%   9.1%  21.5%  13.2%   2.8%  17.2%  20.8%
# Alaska                1.6%  0.7%   8.5%  30.3%  25.2%   8.2%  17.0%   6.5%
# Rhode Island          4.3%  2.8%   8.7%  20.3%  20.5%   7.1%  21.9%  10.9%
# North Dakota          1.4%  1.2%   7.1%  20.3%  20.3%  13.1%  26.1%   7.7%
# Delaware              1.1%  4.8%   9.0%  26.8%  19.1%   7.1%  18.6%  11.0%
# Montana               0.2%  1.9%   8.2%  26.9%  22.1%   9.1%  22.0%   6.9%
# South Dakota          0.3%  3.7%  10.9%  24.6%  16.3%  10.7%  23.7%   7.2%
# Maine                 0.2%  1.5%   5.3%  25.9%  21.0%   9.4%  23.4%  10.1%
#
# Education Level Code      8
# State
# Vermont                3.9%
# Wyoming                1.9%
# District of Columbia  11.3%
# ...

# %%
#Education Level Birth Percentages for Bottom 10 States
percent_df = education_percent_bottom_states.applymap(lambda x: float(x.rstrip('%')))
percent_df.plot(kind='bar', stacked=True, figsize=(12,6), colormap='tab20')

plt.ylabel('Percentage of Births (%)')
plt.title('Education Level Birth Percentages for Bottom 10 States')
plt.legend(title='Education Level', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-69-1192606799.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   percent_df = education_percent_bottom_states.applymap(lambda x: float(x.rstrip('%')))

# %%
#Impact of COVID-19 on U.S. Births (2016–2021)
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import matplotlib.patches as mpatches


births_by_year = df.groupby('Year', as_index=False)['Number of Births'].sum()


total_births = births_by_year['Number of Births'].sum()
births_by_year['Births %'] = (births_by_year['Number of Births'] / total_births) * 100


colors = ['lightgray' if year < 2020 else 'salmon' for year in births_by_year['Year']]


plt.figure(figsize=(8, 5))
plt.bar(births_by_year['Year'], births_by_year['Births %'], color=colors)

plt.title('Impact of COVID-19 on U.S. Births (2016–2021)')
plt.xlabel('Year')
plt.ylabel('Percentage of Total Births')
plt.xticks(births_by_year['Year'])
plt.gca().yaxis.set_major_formatter(FuncFormatter(lambda y, _: f'{y:.0f}%'))

legend_handles = [
    mpatches.Patch(color='lightgray', label='Pre-COVID (2016–2019)'),
    mpatches.Patch(color='salmon', label='COVID Impact (2020–2021)')
]
plt.legend(handles=legend_handles, title='Period')

plt.tight_layout()
plt.show()

# %%
#Percentage of Births by Education Level Code: Pre vs. During/After COVID
df['Period'] = df['Year'].apply(lambda x: 'Pre-COVID' if x < 2020 else 'During/After COVID')
edu_covid = df.groupby(['Education Level Code', 'Period'])['Number of Births'].sum().unstack().fillna(0)
edu_covid_percent = edu_covid.div(edu_covid.sum(axis=1), axis=0) * 100
edu_covid_percent.plot(kind='bar', figsize=(10,6))
plt.title('Percentage of Births by Education Level Code: Pre vs. During/After COVID')
plt.ylabel('Percentage of Births (%)')
plt.xlabel('Education Level Code')
plt.xticks(rotation=0)
plt.legend(title='Period')
plt.tight_layout()
plt.show()

# %%
# Percentage of Births by State: Pre vs. During/After COVID (Top 10 States)
df['Period'] = df['Year'].apply(lambda x: 'Pre-COVID' if x < 2020 else 'During/After COVID')

state_covid = df.groupby(['State', 'Period'])['Number of Births'].sum().unstack().fillna(0)

state_totals = state_covid.sum(axis=1)

state_covid_percent = state_covid.div(state_totals, axis=0) * 100

top_states = state_totals.sort_values(ascending=False).head(10).index
state_covid_percent.loc[top_states].plot(kind='bar', figsize=(12,7))
plt.title('Percentage of Births by State: Pre vs. During/After COVID (Top 10 States)')
plt.ylabel('Percentage of Births (%)')
plt.xlabel('State')
plt.xticks(rotation=45)
plt.legend(title='Period')
plt.tight_layout()
plt.show()

# %% [markdown]
# #Conclusion:
# Between 2016 and 2021, 48.9% of newborns in the United States were female and 51.1% were male, with males having a slightly higher average birth weight (3307 grams) than females (3195 grams). The data show a slight positive trend between maternal age (24 to 36 years) and average birth weight, although other factors also play a significant role.
#
# Most births between 2016 and 2021 were from women aged 25–32, with the highest share (27%) in the 27–28 age group. Births were much lower among women aged 23–24 (3.5%) and especially 35–36 (0.1%). This shows that late twenties to early thirties is the most common age range for childbirth in the U.S.
#
# Maternal age varies by education level: women with doctoral or professional degrees give birth at an average age of 34, those with master’s degrees at 33, while mothers with only a high school diploma or no diploma tend to give birth younger, around 25–26 years. Births are most frequent among women with a high school diploma (25.5%) and bachelor’s degree (20.6%). Overall, 67.1% of births were to mothers without higher education, highlighting a significant educational disparity in birth rates.
#
# From 2016 to 2020, total births in the U.S. declined steadily from approximately 3.95 million to 3.61 million, with a slight increase to 3.66 million in 2021, possibly reflecting recovery following the COVID-19 pandemic.
#
# Regional differences in maternal education are notable. California, one of the states with the highest number of births, shows a diverse range of maternal education levels, predominantly among mothers with high school diplomas and bachelor’s degrees, reflecting its large and socioeconomically varied population. In contrast, states like New York and Illinois have higher proportions of births among mothers with bachelor’s degrees or higher, while Texas and Florida report more births among mothers with less than a high school diploma.
#
# States with fewer births, such as Vermont, North Dakota, and the District of Columbia, often have higher shares of college-educated mothers, indicating demographic and socioeconomic variations.
#
# Overall, U.S. birth trends from 2016 to 2021 highlight the influence of maternal age, education, geography, and external factors like the pandemic on birth outcomes. These insights are crucial for informing public health policies and targeted programs aimed at supporting families and improving maternal and child health.

# %% [markdown]
# #Recommendation:
# - Birth patterns vary by education level and region, so it’s important to design health programs that address the specific needs of different groups. For example, states with more births among less-educated mothers may benefit from increased prenatal education and healthcare access.
#
# - Women with higher education tend to delay childbirth. Providing better healthcare support and flexible work options can help these mothers during pregnancy and after birth.
#
# - Regional differences in birth rates and maternal education should be studied further to ensure resources and services are allocated effectively and equitably.
#
# - The COVID-19 pandemic has impacted birth trends. It’s important to continue monitoring these changes and adjust family planning support as needed.
#
# - Using data to identify groups with higher or lower birth rates by education can help create targeted programs to improve reproductive health awareness and access.
#
# - Improving data quality and consistency across all states will enable better analysis and more effective policy planning.
#
# - Supporting mothers who balance career, education, and childbirth through policies like paid leave and childcare services can improve maternal and child health outcomes.
